# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import concurrent.futures
import os

# === Parameters ===
FEE_RATE = 0.0002      # 0.02%
deviation_mult = 0.5   # Band width multiplier
STOP_LOSS = 0.0005     # 5 bps
TAKE_PROFIT = 0.02    # 10 bps
DATA_DIR = "/content/drive/MyDrive/EBX"  # folder containing CSVs


# === Function to run backtest on one file ===
def run_backtest(file_index):
    file_path = os.path.join(DATA_DIR, f"day{file_index}.csv")
    print(f"Processing {file_path} ...")

    try:
        df = pd.read_csv(file_path)
    except Exception as e:
        print(f"❌ Failed to read {file_path}: {e}")
        return None

    # --- 1. Signal Preparation ---
    df['Signal'] = df['BB17']
    std_dev = df['Price'].rolling(window=10000, min_periods=200).std()
    df['upper_band'] = df['Signal'] + deviation_mult * std_dev
    df['lower_band'] = df['Signal'] - deviation_mult * std_dev
    df['Price'] = df['Price'].rolling(window=300, min_periods=200).mean()
    df['position'] = 0

    # Generate crossover signals
    for i in range(300, len(df)):
        if df['Price'].iloc[i-1] <= df['upper_band'].iloc[i-1] and df['Price'].iloc[i] > df['upper_band'].iloc[i]:
            df.loc[df.index[i], 'position'] = 1
        elif df['Price'].iloc[i-1] >= df['lower_band'].iloc[i-1] and df['Price'].iloc[i] < df['lower_band'].iloc[i]:
            df.loc[df.index[i], 'position'] = -1

    active_pos = 0
    for i in range(len(df)):
        if df['position'].iloc[i] == 1 and active_pos != 1:
            active_pos = 1
        elif df['position'].iloc[i] == -1 and active_pos != -1:
            active_pos = -1
        else:
            df.loc[df.index[i], 'position'] = 0

    # --- 2. Backtest ---
    in_trade = False
    position_type = None
    entry_price = None
    entry_idx = None
    entries, exits, trade_records = [], [], []

    for i in range(1, len(df)):
        signal = df['position'].iloc[i]
        price = df['Price'].iloc[i]
        prev_price = df['Price'].iloc[i-1]
        upper = df['upper_band'].iloc[i]
        lower = df['lower_band'].iloc[i]
        current_idx = df.index[i]

        if in_trade:
            if position_type == 'long':
                if price >= entry_price * (1 + TAKE_PROFIT) or price <= entry_price * (1 - STOP_LOSS):
                    exit_price = price
                    gross_ret = (exit_price - entry_price) / entry_price
                    net_ret = (exit_price * (1 - FEE_RATE) - entry_price * (1 + FEE_RATE)) / (entry_price * (1 + FEE_RATE))
                    trade_records.append({
                        'type': 'long', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = False
                    continue

                if prev_price > upper and price <= upper:  # Reversal
                    exit_price = price
                    gross_ret = (exit_price - entry_price) / entry_price
                    net_ret = (exit_price * (1 - FEE_RATE) - entry_price * (1 + FEE_RATE)) / (entry_price * (1 + FEE_RATE))
                    trade_records.append({
                        'type': 'long', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = True
                    position_type = 'short'
                    entry_price = price
                    entry_idx = current_idx
                    continue

            elif position_type == 'short':
                if price <= entry_price * (1 - TAKE_PROFIT) or price >= entry_price * (1 + STOP_LOSS):
                    exit_price = price
                    gross_ret = (entry_price - exit_price) / entry_price
                    net_ret = (entry_price * (1 - FEE_RATE) - exit_price * (1 + FEE_RATE)) / (entry_price * (1 - FEE_RATE))
                    trade_records.append({
                        'type': 'short', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = False
                    continue

                if prev_price < lower and price >= lower:  # Reversal
                    exit_price = price
                    gross_ret = (entry_price - exit_price) / entry_price
                    net_ret = (entry_price * (1 - FEE_RATE) - exit_price * (1 + FEE_RATE)) / (entry_price * (1 - FEE_RATE))
                    trade_records.append({
                        'type': 'short', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = True
                    position_type = 'long'
                    entry_price = price
                    entry_idx = current_idx
                    continue

        if signal == 1:
            if in_trade and position_type == 'short':
                exit_price = price
                gross_ret = (entry_price - exit_price) / entry_price
                net_ret = (entry_price * (1 - FEE_RATE) - exit_price * (1 + FEE_RATE)) / (entry_price * (1 - FEE_RATE))
                trade_records.append({
                    'type': 'short', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                    'entry_price': entry_price, 'exit_price': exit_price,
                    'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                })
                in_trade = False
            if not in_trade:
                in_trade = True
                position_type = 'long'
                entry_price = price
                entry_idx = current_idx

        elif signal == -1:
            if in_trade and position_type == 'long':
                exit_price = price
                gross_ret = (exit_price - entry_price) / entry_price
                net_ret = (exit_price * (1 - FEE_RATE) - entry_price * (1 + FEE_RATE)) / (entry_price * (1 + FEE_RATE))
                trade_records.append({
                    'type': 'long', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                    'entry_price': entry_price, 'exit_price': exit_price,
                    'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                })
                in_trade = False
            if not in_trade:
                in_trade = True
                position_type = 'short'
                entry_price = price
                entry_idx = current_idx

    # --- Close open trade ---
    if in_trade:
        price = df['Price'].iloc[-1]
        gross_ret = (price - entry_price) / entry_price if position_type == 'long' else (entry_price - price) / entry_price
        net_ret = gross_ret * (1 - FEE_RATE * 2)
        trade_records.append({
            'type': position_type, 'entry_idx': entry_idx, 'exit_idx': df.index[-1],
            'entry_price': entry_price, 'exit_price': price,
            'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
        })

    trades_df = pd.DataFrame(trade_records)
    summary = {
        'file': f"day{file_index}",
        'total_trades': len(trades_df),
        'total_net_return_%': trades_df['net_return_%'].sum() if not trades_df.empty else 0,
        'win_rate_%': len(trades_df[trades_df['net_return_%'] > 0]) / len(trades_df) * 100 if len(trades_df) > 0 else 0
    }

    print(f"✅ Finished {file_path}: {summary}")
    return summary


# === Parallel execution ===
if __name__ == "__main__":
    file_indices = range(50)  # 0–9
    results = []

    with concurrent.futures.ProcessPoolExecutor() as executor:
        for res in executor.map(run_backtest, file_indices):
            if res:
                results.append(res)

    # === Combine results ===
    summary_df = pd.DataFrame(results)
    print("\n=== Overall Summary ===")
    print(summary_df)
    print("\nTOTAL Net Return (%):", summary_df['total_net_return_%'].sum())
    print("AVERAGE Win Rate (%):", summary_df['win_rate_%'].mean())
    print("TOTAL Trades:", summary_df['total_trades'].sum())
# Out:
# Processing /content/drive/MyDrive/EBX/day0.csv ...
# Processing /content/drive/MyDrive/EBX/day1.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day0.csv: {'file': 'day0', 'total_trades': 2, 'total_net_return_%': np.float64(0.4461819051973398), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day2.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day1.csv: {'file': 'day1', 'total_trades': 8, 'total_net_return_%': np.float64(0.28871644030935006), 'win_rate_%': 75.0}
# Processing /content/drive/MyDrive/EBX/day3.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day2.csv: {'file': 'day2', 'total_trades': 5, 'total_net_return_%': np.float64(-0.23400683554177232), 'win_rate_%': 20.0}
# Processing /content/drive/MyDrive/EBX/day4.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day3.csv: {'file': 'day3', 'total_trades': 3, 'total_net_return_%': np.float64(-0.056671161835378916), 'win_rate_%': 33.33333333333333}
# Processing /content/drive/MyDrive/EBX/day5.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day4.csv: {'file': 'day4', 'total_trades': 1, 'total_net_return_%': np.float64(0.8423267477962675), 'win_rate_%': 100.0}
# Processing /content/drive/MyDrive/EBX/day6.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day5.csv: {'file': 'day5', 'total_trades': 5, 'total_net_return_%': np.float64(1.3664159298256573), 'win_rate_%': 20.0}
# Processing /content/drive/MyDrive/EBX/day7.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day6.csv: {'file': 'day6', 'total_trades': 4, 'total_net_return_%': np.float64(-0.10495128870558688), 'win_rate_%': 25.0}
# Processing /content/drive/MyDrive/EBX/day8.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day7.csv: {'file': 'day7', 'total_trades': 5, 'total_net_return_%': np.float64(-0.12785961163707651), 'win_rate_%': 40.0}
# Processing /content/drive/MyDrive/EBX/day9.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day8.csv: {'file': 'day8', 'total_trades': 10, 'total_net_return_%': np.float64(-0.18816110329138733), 'win_rate_%': 30.0}
# Processing /content/drive/MyDrive/EBX/day10.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day9.csv: {'file': 'day9', 'total_trades': 3, 'total_net_return_%': np.float64(-0.11517739074658451), 'win_rate_%': 33.33333333333333}
# Processing /content/drive/MyDrive/EBX/day11.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day10.csv: {'file': 'day10', 'total_trades': 5, 'total_net_return_%': np.float64(1.227750721014392), 'win_rate_%': 80.0}
# Processing /content/drive/MyDrive/EBX/day12.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day11.csv: {'file': 'day11', 'total_trades': 5, 'total_net_return_%': np.float64(-0.124956927124466), 'win_rate_%': 40.0}
# Processing /content/drive/MyDrive/EBX/day13.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day12.csv: {'file': 'day12', 'total_trades': 3, 'total_net_return_%': np.float64(0.357582897079934), 'win_rate_%': 66.66666666666666}
# Processing /content/drive/MyDrive/EBX/day14.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day13.csv: {'file': 'day13', 'total_trades': 9, 'total_net_return_%': np.float64(0.14703769391985935), 'win_rate_%': 55.55555555555556}
# Processing /content/drive/MyDrive/EBX/day15.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day14.csv: {'file': 'day14', 'total_trades': 2, 'total_net_return_%': np.float64(1.934671191524541), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day16.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day15.csv: {'file': 'day15', 'total_trades': 8, 'total_net_return_%': np.float64(-0.27830791640680147), 'win_rate_%': 25.0}
# Processing /content/drive/MyDrive/EBX/day17.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day16.csv: {'file': 'day16', 'total_trades': 4, 'total_net_return_%': np.float64(-0.07522658843233168), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day18.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day17.csv: {'file': 'day17', 'total_trades': 2, 'total_net_return_%': np.float64(-0.12801615154993923), 'win_rate_%': 0.0}
# Processing /content/drive/MyDrive/EBX/day19.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day19.csv: {'file': 'day19', 'total_trades': 5, 'total_net_return_%': np.float64(0.4578204178638857), 'win_rate_%': 60.0}
# Processing /content/drive/MyDrive/EBX/day20.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day18.csv: {'file': 'day18', 'total_trades': 3, 'total_net_return_%': np.float64(0.08744059452798769), 'win_rate_%': 66.66666666666666}
# Processing /content/drive/MyDrive/EBX/day21.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day20.csv: {'file': 'day20', 'total_trades': 5, 'total_net_return_%': np.float64(0.9283232593730337), 'win_rate_%': 80.0}
# Processing /content/drive/MyDrive/EBX/day22.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day21.csv: {'file': 'day21', 'total_trades': 4, 'total_net_return_%': np.float64(1.182412930994321), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day23.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day22.csv: {'file': 'day22', 'total_trades': 4, 'total_net_return_%': np.float64(0.07694807794367223), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day24.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day23.csv: {'file': 'day23', 'total_trades': 6, 'total_net_return_%': np.float64(-0.03687470841684808), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day25.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day24.csv: {'file': 'day24', 'total_trades': 8, 'total_net_return_%': np.float64(0.3648616814608134), 'win_rate_%': 87.5}
# Processing /content/drive/MyDrive/EBX/day26.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day25.csv: {'file': 'day25', 'total_trades': 3, 'total_net_return_%': np.float64(0.7566675862497407), 'win_rate_%': 66.66666666666666}
# Processing /content/drive/MyDrive/EBX/day27.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day26.csv: {'file': 'day26', 'total_trades': 5, 'total_net_return_%': np.float64(-0.03411831235942428), 'win_rate_%': 20.0}
# Processing /content/drive/MyDrive/EBX/day28.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day27.csv: {'file': 'day27', 'total_trades': 9, 'total_net_return_%': np.float64(-0.026909208381128313), 'win_rate_%': 44.44444444444444}
# Processing /content/drive/MyDrive/EBX/day29.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day28.csv: {'file': 'day28', 'total_trades': 9, 'total_net_return_%': np.float64(0.3833428208562068), 'win_rate_%': 22.22222222222222}
# Processing /content/drive/MyDrive/EBX/day30.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day29.csv: {'file': 'day29', 'total_trades': 2, 'total_net_return_%': np.float64(-0.13034465130832823), 'win_rate_%': 0.0}
# Processing /content/drive/MyDrive/EBX/day31.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day30.csv: {'file': 'day30', 'total_trades': 1, 'total_net_return_%': np.float64(0.43912942372161146), 'win_rate_%': 100.0}
# Processing /content/drive/MyDrive/EBX/day32.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day31.csv: {'file': 'day31', 'total_trades': 5, 'total_net_return_%': np.float64(-0.08794105622867748), 'win_rate_%': 20.0}
# Processing /content/drive/MyDrive/EBX/day33.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day33.csv: {'file': 'day33', 'total_trades': 4, 'total_net_return_%': np.float64(1.464716063750016), 'win_rate_%': 50.0}
# Processing /content/drive/MyDrive/EBX/day34.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day32.csv: {'file': 'day32', 'total_trades': 10, 'total_net_return_%': np.float64(0.8088348056949087), 'win_rate_%': 80.0}
# Processing /content/drive/MyDrive/EBX/day35.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day34.csv: {'file': 'day34', 'total_trades': 0, 'total_net_return_%': 0, 'win_rate_%': 0}
# Processing /content/drive/MyDrive/EBX/day36.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day35.csv: {'file': 'day35', 'total_trades': 7, 'total_net_return_%': np.float64(0.04438178487509138), 'win_rate_%': 28.57142857142857}
# Processing /content/drive/MyDrive/EBX/day37.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day36.csv: {'file': 'day36', 'total_trades': 5, 'total_net_return_%': np.float64(-0.2767973155222175), 'win_rate_%': 20.0}
# Processing /content/drive/MyDrive/EBX/day38.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day37.csv: {'file': 'day37', 'total_trades': 4, 'total_net_return_%': np.float64(-0.1043191753868163), 'win_rate_%': 25.0}
# Processing /content/drive/MyDrive/EBX/day39.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day38.csv: {'file': 'day38', 'total_trades': 3, 'total_net_return_%': np.float64(0.10080424262681051), 'win_rate_%': 33.33333333333333}
# Processing /content/drive/MyDrive/EBX/day40.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day39.csv: {'file': 'day39', 'total_trades': 5, 'total_net_return_%': np.float64(-0.1403060895456049), 'win_rate_%': 40.0}
# Processing /content/drive/MyDrive/EBX/day41.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day40.csv: {'file': 'day40', 'total_trades': 6, 'total_net_return_%': np.float64(-0.3582257922728827), 'win_rate_%': 16.666666666666664}
# Processing /content/drive/MyDrive/EBX/day42.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day41.csv: {'file': 'day41', 'total_trades': 7, 'total_net_return_%': np.float64(-0.000304418676541629), 'win_rate_%': 42.857142857142854}
# Processing /content/drive/MyDrive/EBX/day43.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day42.csv: {'file': 'day42', 'total_trades': 7, 'total_net_return_%': np.float64(-0.07629405535860548), 'win_rate_%': 28.57142857142857}
# Processing /content/drive/MyDrive/EBX/day44.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day43.csv: {'file': 'day43', 'total_trades': 6, 'total_net_return_%': np.float64(-0.20311847223684987), 'win_rate_%': 16.666666666666664}
# Processing /content/drive/MyDrive/EBX/day45.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day44.csv: {'file': 'day44', 'total_trades': 5, 'total_net_return_%': np.float64(0.3916282404659415), 'win_rate_%': 80.0}
# Processing /content/drive/MyDrive/EBX/day46.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day45.csv: {'file': 'day45', 'total_trades': 3, 'total_net_return_%': np.float64(0.49009285986666745), 'win_rate_%': 66.66666666666666}
# Processing /content/drive/MyDrive/EBX/day47.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day47.csv: {'file': 'day47', 'total_trades': 3, 'total_net_return_%': np.float64(0.20174003444577526), 'win_rate_%': 66.66666666666666}
# Processing /content/drive/MyDrive/EBX/day48.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day46.csv: {'file': 'day46', 'total_trades': 9, 'total_net_return_%': np.float64(0.1936386966340749), 'win_rate_%': 44.44444444444444}
# Processing /content/drive/MyDrive/EBX/day49.csv ...
# ✅ Finished /content/drive/MyDrive/EBX/day49.csv: {'file': 'day49', 'total_trades': 6, 'total_net_return_%': np.float64(-0.07440314284867827), 'win_rate_%': 33.33333333333333}
# ✅ Finished /content/drive/MyDrive/EBX/day48.csv: {'file': 'day48', 'total_trades': 6, 'total_net_return_%': np.float64(0.008185716338802343), 'win_rate_%': 50.0}
#
# === Overall Summary ===
#      file  total_trades  total_net_return_%  win_rate_%
# 0    day0             2            0.446182   50.000000
# 1    day1             8            0.288716   75.000000
# 2    day2             5           -0.234007   20.000000
# 3    day3             3           -0.056671   33.333333
# 4    day4             1            0.842327  100.000000
# 5    day5             5            1.366416   20.000000
# 6    day6             4           -0.104951   25.000000
# 7    day7             5           -0.127860   40.000000
# 8    day8            10           -0.188161   30.000000
# 9    day9             3           -0.115177   33.333333
# 10  day10             5            1.227751   80.000000
# 11  day11             5           -0.124957   40.000000
# 12  day12             3            0.357583   66.666667
# 13  day13             9            0.147038   55.555556
# 14  day14             2            1.934671   50.000000
# 15  day15             8           -0.278308   25.000000
# 16  day16             4           -0.075227   50.000000
# 17  day17             2           -0.128016    0.000000
# 18  day18             3            0.087441   66.666667
# 19  day19             5            0.457820   60.000000
# 20  day20             5            0.928323   80.000000
# 21  day21             4            1.182413   50.000000
# 22  day22             4            0.076948   50.000000
# 23  day23             6           -0.036875   50.000000
# 24  day24             8            0.364862   87.500000
# 25  day25             3            0.756668   66.666667
# 26  day26             5           -0.034118   20.000000
# 27  day27             9           -0.026909   44.444444
# 28  day28             9            0.383343   22.222222
# 29  day29             2           -0.130345    0.000000
# 30  day30             1            0.439129  100.000000
# 31  day31             5           -0.087941   20.000000
# 32  day32            10            0.808835   80.000000
# 33  day33             4            1.464716   50.000000
# 34  day34             0            0.000000    0.000000
# 35  day35             7            0.044382   28.571429
# 36  day36             5           -0.276797   20.000000
# 37  day37             4           -0.104319   25.000000
# 38  day38             3            0.100804   33.333333
# 39  day39             5           -0.140306   40.000000
# 40  day40             6           -0.358226   16.666667
# 41  day41             7           -0.000304   42.857143
# 42  day42             7           -0.076294   28.571429
# 43  day43             6           -0.203118   16.666667
# 44  day44             5            0.391628   80.000000
# 45  day45             3            0.490093   66.666667
# 46  day46             9            0.193639   44.444444
# 47  day47             3            0.201740   66.666667
# 48  day48             6            0.008186   50.000000
# 49  day49             6           -0.074403   33.333333
#
# TOTAL Net Return (%): 12.008361390542774
# AVERAGE Win Rate (%): 44.68333333333334
# TOTAL Trades: 249

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import concurrent.futures
import os

# === Parameters ===
FEE_RATE = 0.0002      # 0.02%
deviation_mult = 0.5   # Band width multiplier
STOP_LOSS = 0.0005     # 5 bps
TAKE_PROFIT = 0.02    # 10 bps
DATA_DIR = "/content/drive/MyDrive/EBX"  # folder containing CSVs


# === Function to run backtest on one file ===
def run_backtest(file_index):
    file_path = os.path.join(DATA_DIR, f"day{file_index}.csv")
    print(f"Processing {file_path} ...")

    try:
        df = pd.read_csv(file_path)
    except Exception as e:
        print(f"❌ Failed to read {file_path}: {e}")
        return None

    # --- 1. Signal Preparation ---
    df['Signal'] = df['BB17']
    std_dev = df['Price'].rolling(window=10000, min_periods=200).std()
    df['upper_band'] = df['Signal'] + deviation_mult * std_dev
    df['lower_band'] = df['Signal'] - deviation_mult * std_dev
    df['Price'] = df['Price'].rolling(window=300, min_periods=200).mean()
    df['position'] = 0

    # Generate crossover signals
    for i in range(300, len(df)):
        if df['Price'].iloc[i-1] <= df['upper_band'].iloc[i-1] and df['Price'].iloc[i] > df['upper_band'].iloc[i]:
            df.loc[df.index[i], 'position'] = 1
        elif df['Price'].iloc[i-1] >= df['lower_band'].iloc[i-1] and df['Price'].iloc[i] < df['lower_band'].iloc[i]:
            df.loc[df.index[i], 'position'] = -1

    active_pos = 0
    for i in range(len(df)):
        if df['position'].iloc[i] == 1 and active_pos != 1:
            active_pos = 1
        elif df['position'].iloc[i] == -1 and active_pos != -1:
            active_pos = -1
        else:
            df.loc[df.index[i], 'position'] = 0

    # --- 2. Backtest ---
    in_trade = False
    position_type = None
    entry_price = None
    entry_idx = None
    entries, exits, trade_records = [], [], []

    for i in range(1, len(df)):
        signal = df['position'].iloc[i]
        price = df['Price'].iloc[i]
        prev_price = df['Price'].iloc[i-1]
        upper = df['upper_band'].iloc[i]
        lower = df['lower_band'].iloc[i]
        current_idx = df.index[i]

        if in_trade:
            if position_type == 'long':
                if price >= entry_price * (1 + TAKE_PROFIT) or price <= entry_price * (1 - STOP_LOSS):
                    exit_price = price
                    gross_ret = (exit_price - entry_price) / entry_price
                    net_ret = (exit_price * (1 - FEE_RATE) - entry_price * (1 + FEE_RATE)) / (entry_price * (1 + FEE_RATE))
                    trade_records.append({
                        'type': 'long', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = False
                    continue

                if prev_price > upper and price <= upper:  # Reversal
                    exit_price = price
                    gross_ret = (exit_price - entry_price) / entry_price
                    net_ret = (exit_price * (1 - FEE_RATE) - entry_price * (1 + FEE_RATE)) / (entry_price * (1 + FEE_RATE))
                    trade_records.append({
                        'type': 'long', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = True
                    position_type = 'short'
                    entry_price = price
                    entry_idx = current_idx
                    continue

            elif position_type == 'short':
                if price <= entry_price * (1 - TAKE_PROFIT) or price >= entry_price * (1 + STOP_LOSS):
                    exit_price = price
                    gross_ret = (entry_price - exit_price) / entry_price
                    net_ret = (entry_price * (1 - FEE_RATE) - exit_price * (1 + FEE_RATE)) / (entry_price * (1 - FEE_RATE))
                    trade_records.append({
                        'type': 'short', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = False
                    continue

                if prev_price < lower and price >= lower:  # Reversal
                    exit_price = price
                    gross_ret = (entry_price - exit_price) / entry_price
                    net_ret = (entry_price * (1 - FEE_RATE) - exit_price * (1 + FEE_RATE)) / (entry_price * (1 - FEE_RATE))
                    trade_records.append({
                        'type': 'short', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                        'entry_price': entry_price, 'exit_price': exit_price,
                        'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                    })
                    in_trade = True
                    position_type = 'long'
                    entry_price = price
                    entry_idx = current_idx
                    continue

        if signal == 1:
            if in_trade and position_type == 'short':
                exit_price = price
                gross_ret = (entry_price - exit_price) / entry_price
                net_ret = (entry_price * (1 - FEE_RATE) - exit_price * (1 + FEE_RATE)) / (entry_price * (1 - FEE_RATE))
                trade_records.append({
                    'type': 'short', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                    'entry_price': entry_price, 'exit_price': exit_price,
                    'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                })
                in_trade = False
            if not in_trade:
                in_trade = True
                position_type = 'long'
                entry_price = price
                entry_idx = current_idx

        elif signal == -1:
            if in_trade and position_type == 'long':
                exit_price = price
                gross_ret = (exit_price - entry_price) / entry_price
                net_ret = (exit_price * (1 - FEE_RATE) - entry_price * (1 + FEE_RATE)) / (entry_price * (1 + FEE_RATE))
                trade_records.append({
                    'type': 'long', 'entry_idx': entry_idx, 'exit_idx': current_idx,
                    'entry_price': entry_price, 'exit_price': exit_price,
                    'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
                })
                in_trade = False
            if not in_trade:
                in_trade = True
                position_type = 'short'
                entry_price = price
                entry_idx = current_idx

    # --- Close open trade ---
    if in_trade:
        price = df['Price'].iloc[-1]
        gross_ret = (price - entry_price) / entry_price if position_type == 'long' else (entry_price - price) / entry_price
        net_ret = gross_ret * (1 - FEE_RATE * 2)
        trade_records.append({
            'type': position_type, 'entry_idx': entry_idx, 'exit_idx': df.index[-1],
            'entry_price': entry_price, 'exit_price': price,
            'gross_return_%': gross_ret * 100, 'net_return_%': net_ret * 100
        })

    trades_df = pd.DataFrame(trade_records)
    summary = {
        'file': f"day{file_index}",
        'total_trades': len(trades_df),
        'total_net_return_%': trades_df['net_return_%'].sum() if not trades_df.empty else 0,
        'win_rate_%': len(trades_df[trades_df['net_return_%'] > 0]) / len(trades_df) * 100 if len(trades_df) > 0 else 0
    }

    print(f"✅ Finished {file_path}: {summary}")
    return summary


# === Parallel execution ===
if __name__ == "__main__":
    file_indices = range(50)  # 0–9
    results = []

    with concurrent.futures.ProcessPoolExecutor() as executor:
        for res in executor.map(run_backtest, file_indices):
            if res:
                results.append(res)

    # === Combine results ===
    summary_df = pd.DataFrame(results)
    print("\n=== Overall Summary ===")
    print(summary_df)
    print("\nTOTAL Net Return (%):", summary_df['total_net_return_%'].sum())
    print("AVERAGE Win Rate (%):", summary_df['win_rate_%'].mean())
    print("TOTAL Trades:", summary_df['total_trades'].sum())
